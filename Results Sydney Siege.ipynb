# %%
#RF

# %% [markdown]
# #### Importing required libraries

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")

experiments = mlflow.search_experiments(
    filter_string="name LIKE '%charlie%'"
)

for exp in experiments:
    print(f"ID: {exp.experiment_id} | Name: {exp.name}")
# Out:
# ID: 129 | Name: HAN 2026-07-12 charlie_hebdo
# ID: 128 | Name: LSTM 2026-07-11 charlie_hebdo
# ID: 127 | Name: LSTM 2026-07-11 charlie_hebdo run
# ID: 122 | Name: HAN 2026-07-05 charlie_hebdo
# ID: 121 | Name: Random Forest 2026-07-05 charlie_hebdo run
# ID: 120 | Name: LSTM 2026-06-02 charlie_hebdo run'
# ID: 118 | Name: HAN 2026-07-04 charlie_hebdo
# ID: 94 | Name: Light GBM 2026-06-06 charlie_hebdo run
# ID: 93 | Name: GAT 2026-06-06 charlie_hebdo
# ID: 80 | Name: LSTM 2026-06-02 charlie_hebdo run
# ID: 79 | Name: LSTM 2026-05-31 charlie_hebdo run
# ID: 77 | Name: GAT 2026-05-26 charlie_hebdo run
# ID: 76 | Name: 'HAN 2026-05-25 charlie_hebdo run
# ID: 75 | Name: Random Forest 2026-05-25 charlie_hebdo run
# ID: 74 | Name: Light GBM 2026-05-25 charlie_hebdo run
# ID: 73 | Name: HAN 2026-05-25 charlie_hebdo run
# ID: 72 | Name: GAT 2026-05-25 charlie_hebdo run
# ID: 71 | Name: LSTM 2026-05-25 charlie_hebdo run
# ID: 70 | Name: HAN 2026-05-25 charlie_hebdo
# ID: 69 | Name: Random Forest 2026-05-25 charlie_hebdo
# ID: 68 | Name: Random Forest 2026-05-25 charlie-hebdo
# ID: 66 | Name: Light GBM 2026-05-25 charlie_hebdo
# ID: 65 | Name: GAT 2026-05-25 charlie_hebdo
# ID: 64 | Name: GAT 2026-05-24 charlie_hebdo
# ID: 63 | Name: Light GBM 2026-04-26 charlie_hebdo
# ID: 62 | Name: LSTM 2026-04-26 charlie_hebdo run
# ID: 61 | Name: LSTM 2026-04-19 charlie_hebdo run
# ID: 58 | Name: LSTM 2026-04-18 charlie_hebdo
# ID: 55 | Name: LSTM 2026-04-18 charlie_hebdo run
# ID: 54 | Name: LSTM 2026-04-18 charlie-hebdo run
# ID: 39 | Name: Random Forest 2026-04-11 charlie_hebdo run
# ID: 38 | Name: Random Forest 2026-04-11 charlie_hebdo
# ID: 33 | Name: Light GBM 2026-04-09 charlie_hebdo
# ID: 32 | Name: Light GBM 2026-04-09 charlie-hebdo run
# ID: 31 | Name: Random Forest 2026-04-09 charlie_hebdo run
# ID: 30 | Name: Random Forest 2026-04-09 charlie-hebdo run
# ID: 21 | Name: Light GBM 2026-04-05 charlie_hebdo
# ID: 16 | Name: HAN 2026-03-29 charlie_hebdo
# ID: 8 | Name: GAT 2026-03-28 charlie_hebdo run

# %%
import matplotlib.pyplot as plt 
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
import seaborn as sns
import pandas as pd
import matplotlib.pylab as plt
from utils import Hetero_Data_Processor_Filter_on_Test_since_first_post
import warnings 
warnings.filterwarnings("ignore")
import logging

import os
os.environ["MLFLOW_ENABLE_ARTIFACTS_PROGRESS_BAR"] = "false"
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
event_name ="sydneysiege"
df_posts_by_time_cut = pd.read_pickle(f'replies_{event_name}.pkl')

df_posts_by_time_cut['min_since_fst_post'] = round(
            (df_posts_by_time_cut['time'] - df_posts_by_time_cut['time'].min()).dt.total_seconds() / 60, 2)

# %%
df_metrics = df_posts_by_time_cut[['id','time','rumour','min_since_fst_post']].drop_duplicates().sort_values(by='time')

# %%
file_path_replies = f"replies_{event_name}.pkl"
file_path_posts = f"posts_{event_name}.pkl"


processor = Hetero_Data_Processor_Filter_on_Test_since_first_post(file_path_replies, file_path_posts, time_cut=10000)
data = processor.process()

# %%
start = df_metrics.iloc[int(data['id'].train_mask.sum()):].min_since_fst_post.min()
end = df_metrics.iloc[int(data['id'].train_mask.sum()):].min_since_fst_post.max()
duration = end-start
experiment_time= duration+60
print("Start", round(start/60,2))
print("End:", round(end/60,2))
print("Duration", round(experiment_time/60,2))
# Out:
# Start 11.79
# End: 16.93
# Duration 6.15

# %%
bad_rate_train = df_metrics.iloc[:int(data['id'].train_mask.sum())]['rumour'].sum()\
                    /df_metrics.iloc[:int(data['id'].train_mask.sum())].shape[0]

bad_rate_test = df_metrics.iloc[int(data['id'].train_mask.sum()):].rumour.sum()\
            /df_metrics.iloc[int(data['id'].train_mask.sum()):].shape[0]

print("Bad_rate Train",bad_rate_train)
print("Bad_rate Test",bad_rate_test)
# Out:
# Bad_rate Train 0.4719512195121951
# Bad_rate Test 0.3181818181818182

# %%
cut=int(bad_rate_train/2*100)
print(cut)
# Out:
# 23

# %% [markdown]
# #### HAN model

# %%
experiment = mlflow.get_experiment_by_name(f'HAN 2026-06-02 {event_name} run')
print(experiment.name)

if experiment is not None:
    experiment_id = experiment.experiment_id

    # Retrieve all runs in the experiment as a DataFrame
    df_han = mlflow.search_runs(experiment_ids=[experiment_id]).dropna(subset='end_time')
    
    # Show the DataFrame
    #print(df)
else:
    print(f"Experiment '{experiment_name}' not found.")
# Out:
# HAN 2026-06-02 sydneysiege run

# %%
dfs=[]

for run_id in list(df_han.run_id):
    try:
        path = mlflow.artifacts.download_artifacts(
            run_id=run_id,
            artifact_path=f"metrics_by_bucket_new_posts_{event_name}_HAN.csv"
        )
        df = pd.read_csv(path)
        df["run_id"] = run_id  # track source
        #df["time_cut"] =df_gat[df_gat.run_id==run_id]['metrics.time_cut']

        dfs.append(df)
    except Exception:
        pass  # skip runs without the artifact

df_all = pd.concat(dfs, ignore_index=True)
df_all = df_all.merge(df_han[['run_id','metrics.time_cut']],on='run_id',how='left')
df_all.rename(columns={'Rumour s_captured':'frauds_captured'},inplace=True)

# %%
df_all.sort_values(by='metrics.time_cut',ascending=True,inplace=True)

# %%
df_all['hour']= round(df_all['metrics.time_cut']/60,2)
df_posts_by_time_cut = pd.DataFrame(df_all.groupby('metrics.time_cut')['records'].max())
df_fakes_by_time_cut = pd.DataFrame(df_all.groupby('metrics.time_cut')['frauds_captured'].max())
df_posts_by_time_cut.rename(columns={'records':'total_posts'},inplace=True)
df_fakes_by_time_cut.rename(columns={'frauds_captured':'total_fake'},inplace=True)
df_all = df_all.merge(df_posts_by_time_cut, on='metrics.time_cut',how='left')
df_all = df_all.merge(df_fakes_by_time_cut, on='metrics.time_cut',how='left')
df_all.capture_rate = round(df_all.capture_rate,3)
df_all.false_positive_rate = round(df_all.false_positive_rate,3)
df_all = df_all[(df_all['percentile']==cut)]
df_all['false_positive_rate'] = (df_all['records']-df_all['frauds_captured'])/\
                    ( (df_all['records']-df_all['frauds_captured']) +  (df_all['total_posts']-df_all['records']) )

# %%
pd.set_option('display.max_rows',None)

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Capture Rate
fig.add_trace(
    go.Scatter(
        x=df_all["hour"],
        y=df_all["capture_rate"],
        mode="lines+markers",
        name="Capture Rate",
        yaxis="y1"
    )
)

# Bad Rate
fig.add_trace(
    go.Scatter(
        x=df_all["hour"],
        y=df_all["false_positive_rate"],
        mode="lines+markers",
        name="False Positive Rate",
        yaxis="y1"
    )
)

# Total Posts (secondary axis)
fig.add_trace(
    go.Bar(
        x=df_all["hour"],
        y=df_all["total_posts"],
        name="Total Posts",
        # mode="lines+markers",
        yaxis="y2",
        opacity=1
    )
)

# Layout with dual axis
fig.update_layout(
    title="Capture Rate, FP Rate, and Total Posts by Hour",
    xaxis=dict(title="Hour"),
    yaxis=dict(title="Rates", side="left"),
    yaxis2=dict(
        title="Total Posts",
        overlaying="y",
        side="right"
    ),
    legend=dict(
        orientation="h",      # horizontal legend
        yanchor="top",
        y=-0.2,               # move below plot
        xanchor="center",
        x=0.5                 # center horizontally
    ),
    template="plotly_white"
)

fig.show()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="90274c44-b55d-413b-9d36-c5a57e996278" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("90274c44-b55d-413b-9d36-c5a57e996278")) {                    Plotly.newPlot(                        "90274c44-b55d-413b-9d36-c5a57e996278",                        [{"mode":"lines+markers","name":"Capture Rate","x":{"dtype":"f8","bdata":"mpmZmZmZuT+kcD0K16PAPwrXo3A9Csc\u002fmpmZmZmZyT9xPQrXo3DNPzMzMzMzM9M\u002frkfhehSu1z+amZmZmZnZP4XrUbgehds\u002fzczMzMzM3D\u002f2KFyPwvXgP4\u002fC9Shcj+I\u002fMzMzMzMz4z\u002fXo3A9CtfjP3E9CtejcOU\u002fAAAAAAAA6D+amZmZmZnpP9ejcD0K1+s\u002fcT0K16Nw7T9mZmZmZmbuPwAAAAAAAPA\u002fexSuR+F68D\u002fNzMzMzMzwPxSuR+F6FPI\u002fuB6F61G48j\u002fhehSuR+HyPzMzMzMzM\u002fM\u002fAAAAAAAA9D9SuB6F61H0P83MzMzMzPQ\u002f7FG4HoXr9T8U
9CtejcOE\u002fH4XrUbge3T8fhetRuB7dP9ejcD0K19s\u002f16NwPQrX2z\u002fXo3A9CtfbP9ejcD0K19s\u002fEoPAyqFF1j9kO99PjZfeP2Q730+Nl94\u002f16NwPQrX2z\u002fXo3A9CtfbP2Q730+Nl94\u002fZDvfT42X3j9OYhBYObTgPw4tsp3vp+I\u002fAAAAAAAA4D8zMzMzMzPjPzMzMzMzM+M\u002f7FG4HoXr4T8zMzMzMzPjP3sUrkfheuQ\u002fuB6F61G43j\u002fsUbgehevhP6RwPQrXo+A\u002fmG4Sg8DK4T\u002fwp8ZLN4nhP5ZDi2zn++E\u002fAAAAAAAA4D+TGARWDi3iPxkEVg4tsuE\u002fzczMzMzM4D8fhetRuB7hP3E9CtejcOE\u002f30+Nl24S4z8Sg8DKoUXiP6jGSzeJQeA\u002fF9nO91Pj3T9qvHSTGATeP8uhRbbz\u002fdw\u002fFK5H4XoU3j9aZDvfT43fP0w3iUFg5eA\u002fd76fGi\u002fd4D\u002f+1HjpJjHgPwAAAAAAAOA\u002fBFYOLbKd3z\u002f6fmq8dJPgPxBYObTIdt4\u002fDAIrhxbZ3j+6SQwCK4fePycxCKwcWtw\u002fiUFg5dAi2z8X2c73U+PdP2q8dJMYBN4\u002fvHSTGARW3j8nMQisHFrcP2q8dJMYBN4\u002fzczMzMzM3D8fhetRuB7dP+Olm8QgsNo\u002fhxbZzvdT2z89CtejcD3aP90kBoGVQ9s\u002fO99PjZdu2j+wcmiR7XzXP57vp8ZLN9k\u002fsp3vp8ZL1z8="},"yaxis":"y","type":"scatter"},{"mode":"lines+markers","name":"False Positive Rate","x":{"dtype":"f8","bdata":"mpmZmZmZuT+kcD0K16PAPwrXo3A9Csc\u002fmpmZmZmZyT9xPQrXo3DNPzMzMzMzM9M\u002frkfhehSu1z+amZmZmZnZP4XrUbgehds\u002fzczMzMzM3D\u002f2KFyPwvXgP4\u002fC9Shcj+I\u002fMzMzMzMz4z\u002fXo3A9CtfjP3E9CtejcOU\u002fAAAAAAAA6D+amZmZmZnpP ...

# %%
print("bad_rate_test",round(bad_rate_test*100,2))
print('Rumour  Capture rate: ',float(round(df_all.frauds_captured.sum()/df_all.total_fake.sum()*100,2)))
print('False Positive rate: ',float(round((df_all.records.sum()- df_all.frauds_captured.sum())/df_all.total_posts.sum()*100,2)))
# Out:
# bad_rate_test 31.82
# Rumour  Capture rate:  48.07
# False Positive rate:  13.4

# %%
df_han_all =df_all.copy()
#df_han_all = df_han_all[df_han_all.total_posts/df_han_all.total_posts.max()>=0.1]
df_han_all['model'] ='HAN'

# %% [markdown]
# #### GAT model

# %%
experiment = mlflow.get_experiment_by_name(f'GAT 2026-06-04 {event_name} run')
print(experiment.name)

if experiment is not None:
    experiment_id = experiment.experiment_id

    # Retrieve all runs in the experiment as a DataFrame
    df_gat = mlflow.search_runs(experiment_ids=[experiment_id]).dropna(subset='metrics.time_cut')
    
    # Show the DataFrame
    #print(df)
else:
    print(f"Experiment '{experiment_name}' not found.")
# Out:
# GAT 2026-06-04 sydneysiege run

# %%
dfs=[]

for run_id in list(df_gat.run_id):
    try:
        path = mlflow.artifacts.download_artifacts(
            run_id=run_id,
  artifact_path=f"metrics_by_bucket_new_posts_{event_name}_GAT.csv"
        )
        df = pd.read_csv(path)
        df["run_id"] = run_id  # track source
        #df["time_cut"] =df_gat[df_gat.run_id==run_id]['metrics.time_cut']

        dfs.append(df)
    except Exception:
        pass  # skip runs without the artifact

df_all = pd.concat(dfs, ignore_index=True)
df_all = df_all.merge(df_gat[['run_id','metrics.time_cut']],on='run_id',how='left')
df_all.rename(columns={'Rumour s_captured':'frauds_captured'},inplace=True)

# %%
df_all.sort_values(by='metrics.time_cut',ascending=True,inplace=True)

# %%
df_all['hour']= round(df_all['metrics.time_cut']/60,2)
df_posts_by_time_cut = pd.DataFrame(df_all.groupby('metrics.time_cut')['records'].max())
df_fakes_by_time_cut = pd.DataFrame(df_all.groupby('metrics.time_cut')['frauds_captured'].max())
df_posts_by_time_cut.rename(columns={'records':'total_posts'},inplace=True)
df_fakes_by_time_cut.rename(columns={'frauds_captured':'total_fake'},inplace=True)
df_all = df_all.merge(df_posts_by_time_cut, on='metrics.time_cut',how='left')
df_all = df_all.merge(df_fakes_by_time_cut, on='metrics.time_cut',how='left')
df_all.capture_rate = round(df_all.capture_rate,3)
df_all.false_positive_rate = round(df_all.false_positive_rate,3)

df_all = df_all[(df_all['percentile']==cut)]
df_all = df_all[df_all.total_posts<50]


df_all['total_posts'] = df_all.total_posts.cumsum()
df_all['total_fake'] = df_all.total_fake.cumsum()
df_all['frauds_captured'] = df_all.frauds_captured.cumsum()
df_all['records'] = df_all.records.cumsum()
df_all['capture_rate'] = df_all['frauds_captured'] /df_all['total_fake'] 
df_all['false_positive_rate'] = (df_all['records']-df_all['frauds_captured'])/\
                    ( (df_all['records']-df_all['frauds_captured']) +  (df_all['total_posts']-df_all['records']) )

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Capture Rate
fig.add_trace(
    go.Scatter(
        x=df_all["hour"],
        y=df_all["capture_rate"],
        mode="lines+markers",
        name="Capture Rate",
        yaxis="y1"
    )
)

# Bad Rate
fig.add_trace(
    go.Scatter(
        x=df_all["hour"],
        y=df_all["false_positive_rate"],
        mode="lines+markers",
        name="False Positive Rate",
        yaxis="y1"
    )
)

# Total Posts (secondary axis)
fig.add_trace(
    go.Bar(
        x=df_all["hour"],
        y=df_all["total_posts"],
        name="Total Posts",
        # mode="lines+markers",
        yaxis="y2",
        opacity=1
    )
)

# Layout with dual axis
fig.update_layout(
    title="Capture Rate, FP Rate, and Total Posts by Hour",
    xaxis=dict(title="Hour"),
    yaxis=dict(title="Rates", side="left"),
    yaxis2=dict(
        title="Total Posts",
        overlaying="y",
        side="right"
    ),
    legend=dict(
        orientation="h",      # horizontal legend
        yanchor="top",
        y=-0.2,               # move below plot
        xanchor="center",
        x=0.5                 # center horizontally
    ),
    template="plotly_white"
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3
# %%
print("bad_rate_test",round(bad_rate_test*100,2))
print('Rumour  Capture rate: ',float(round(df_all.frauds_captured.sum()/df_all.total_fake.sum()*100,2)))
print('False Positive rate: ',float(round((df_all.records.sum()- df_all.frauds_captured.sum())/df_all.total_posts.sum()*100,2)))
# Out:
# bad_rate_test 31.82
# Rumour  Capture rate:  38.39
# False Positive rate:  46.23

# %%
df_gat_all =df_all.copy()
#df_gat_all = df_gat_all[df_gat_all.total_posts/df_gat_all.total_posts.max()>=0.1]
df_gat_all['model'] ='GAT'

# %% [markdown]
# #### LSTM model

# %%
experiment = mlflow.get_experiment_by_name(f'LSTM 2026-07-04 {event_name} run')
print(experiment.name)

if experiment is not None:
    experiment_id = experiment.experiment_id

    # Retrieve all runs in the experiment as a DataFrame
    df_lstm = mlflow.search_runs(experiment_ids=[experiment_id]).dropna(subset='end_time')
    
    # Show the DataFrame
    #print(df)
else:
    print(f"Experiment '{experiment_name}' not found.")
# Out:
# LSTM 2026-07-04 sydneysiege run

# %%
dfs=[]

for run_id in list(df_lstm.run_id):
    try:
        path = mlflow.artifacts.download_artifacts(
            run_id=run_id,
            artifact_path=f"metrics_by_bucket_new_posts_{event_name}_LSTM.csv"
        )
        df = pd.read_csv(path)
        df["run_id"] = run_id  # track source
        #print(df.shape)
        #df["time_cut"] =df_gat[df_gat.run_id==run_id]['metrics.time_cut']

        dfs.append(df)
    except Exception:
        pass  # skip runs without the artifact

df_all = pd.concat(dfs, ignore_index=True)
df_all = df_all.merge(df_lstm[['run_id','metrics.time_cut']],on='run_id',how='left')
df_all.rename(columns={'Rumour s_captured':'frauds_captured'},inplace=True)

# %%
df_all.sort_values(by='metrics.time_cut',ascending=True,inplace=True)

df_all['hour']= round(df_all['metrics.time_cut']/60,2)
df_posts_by_time_cut = pd.DataFrame(df_all.groupby('metrics.time_cut')['records'].max())
df_fakes_by_time_cut = pd.DataFrame(df_all.groupby('metrics.time_cut')['frauds_captured'].max())
df_posts_by_time_cut.rename(columns={'records':'total_posts'},inplace=True)
df_fakes_by_time_cut.rename(columns={'frauds_captured':'total_fake'},inplace=True)
df_all = df_all.merge(df_posts_by_time_cut, on='metrics.time_cut',how='left')
df_all = df_all.merge(df_fakes_by_time_cut, on='metrics.time_cut',how='left')
df_all.capture_rate = round(df_all.capture_rate,3)
df_all.false_positive_rate = round(df_all.false_positive_rate,3)
df_all = df_all[df_all.total_posts<50]
df_all = df_all[(df_all['percentile']==cut)]


df_all['total_posts'] = df_all.total_posts.cumsum()
df_all['total_fake'] = df_all.total_fake.cumsum()
df_all['frauds_captured'] = df_all.frauds_captured.cumsum()
df_all['records'] = df_all.records.cumsum()
df_all['capture_rate'] = df_all['frauds_captured'] /df_all['total_fake'] 
df_all['false_positive_rate'] = (df_all['records']-df_all['frauds_captured'])/\
                    ( (df_all['records']-df_all['frauds_captured']) +  (df_all['total_posts']-df_all['records']) )


df_all['false_positive_rate'] = (df_all['records']-df_all['frauds_captured'])/\
                    ( (df_all['records']-df_all['frauds_captured']) +  (df_all['total_posts']-df_all['records']) )

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Capture Rate
fig.add_trace(
    go.Scatter(
        x=df_all["hour"],
        y=df_all["capture_rate"],
        mode="lines+markers",
        name="Capture Rate",
        yaxis="y1"
    )
)

# Bad Rate
fig.add_trace(
    go.Scatter(
        x=df_all["hour"],
        y=df_all["false_positive_rate"],
        mode="lines+markers",
        name="False Positive Rate",
        yaxis="y1"
    )
)

# Total Posts (secondary axis)
fig.add_trace(
    go.Bar(
        x=df_all["hour"],
        y=df_all["total_posts"],
        name="Total Posts",
        # mode="lines+markers",
        yaxis="y2",
        opacity=1
    )
)

# Layout with dual axis
fig.update_layout(
    title="Capture Rate, FP Rate, and Total Posts by Hour",
    xaxis=dict(title="Hour"),
    yaxis=dict(title="Rates", side="left"),
    yaxis2=dict(
        title="Total Posts",
        overlaying="y",
        side="right"
    ),
    legend=dict(
        orientation="h",      # horizontal legend
        yanchor="top",
        y=-0.2,               # move below plot
        xanchor="center",
        x=0.5                 # center horizontally
    ),
    template="plotly_white"
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="4375a210-8c9a-4808-89e1-d77cc9463064" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4375a210-8c9a-4808-89e1-d77cc9463064")) {                    Plotly.newPlot(                        "4375a210-8c9a-4808-89e1-d77cc9463064",                        [{"mode":"lines+markers","name":"Capture Rate","x":{"dtype":"f8","bdata":"CtejcD0Kxz+amZmZmZnJP3E9CtejcM0\u002fMzMzMzMz0z97FK5H4XrUP65H4XoUrtc\u002fmpmZmZmZ2T+F61G4HoXbPxSuR+F6FN4\u002f9ihcj8L14D+PwvUoXI\u002fiP9ejcD0K1+M\u002fcT0K16Nw5T8AAAAAAADoP5qZmZmZmek\u002f16NwPQrX6z9xPQrXo3DtPwAAAAAAAPA\u002fzczMzMzM8D8UrkfhehTyP7gehetRuPI\u002f4XoUrkfh8j8zMzMzMzPzPwAAAAAAAPQ\u002fUrgehetR9D\u002fNzMzMzMz0P+xRuB6F6\u002fU\u002fFK5H4XoU9j\u002fhehSuR+H2PzMzMzMzM\u002fc\u002frkfhehSu9z9SuB6F61H4P3sUrkfhevg\u002fSOF6FK5H+T+amZmZmZn5P2ZmZmZmZvo\u002frkfhehSu+z9SuB6F61H8P3sUrkfhevw\u002fzczMzMzM\u002fD8UrkfhehT+P2ZmZmZmZv4\u002fMzMzMzMz\u002fz+uR+F6FK7\u002fP6RwPQrXowBAMzMzMzMzAUBcj8L1KFwBQHE9CtejcAFA16NwPQrXAUAAAAAAAAACQArXo3A9CgNAKVyPwvUoBEBmZmZmZmYEQI\u002fC9ShcjwRAzczMzMzMBEBcj8L1KFwFQJqZmZmZmQVAPQrXo3A9BkDNzMzMzMwGQArXo3A9CgdAw
LzcP+0b1r5h7ds\u002fJUmSJEmS3D8EDSd1Xx7bP\u002fwUlwzBOto\u002fAAAAAAAA2j822WSTTTbZP3h4eHh4eNg\u002fOY7jOI7j2D\u002fLli1btmzZP72G8hrKa9g\u002f\u002fa4WN2F+1z\u002fzwyJl4OnWP\u002fPDImXg6dY\u002f0tT5tYdc1j+3bdu2bdvWP5eWlpaWltY\u002fRhdddNFF1z8XbMEWbMHWP29605ve9NY\u002fVz\u002foqMAX1z9XP+iowBfXP7dt27Zt29Y\u002fZmZmZmZm1j9qHuSuny3WP\u002fb19fX19dU\u002fIz6BVHJe1j9P7MRO7MTWP13Lwc1+IdY\u002fTGgvob2E1j\u002f+ZAls2k\u002fWP\u002f5kCWzaT9Y\u002f\u002fmQJbNpP1j\u002f+ZAls2k\u002fWP5IkSZIkSdY\u002f"},"yaxis":"y","type":"scatter"},{"mode":"lines+markers","name":"False Positive Rate","x":{"dtype":"f8","bdata":"CtejcD0Kxz+amZmZmZnJP3E9CtejcM0\u002fMzMzMzMz0z97FK5H4XrUP65H4XoUrtc\u002fmpmZmZmZ2T+F61G4HoXbPxSuR+F6FN4\u002f9ihcj8L14D+PwvUoXI\u002fiP9ejcD0K1+M\u002fcT0K16Nw5T8AAAAAAADoP5qZmZmZmek\u002f16NwPQrX6z9xPQrXo3DtPwAAAAAAAPA\u002fzczMzMzM8D8UrkfhehTyP7ge ...

# %%
print("bad_rate_test",round(bad_rate_test*100,2))
print('Rumour  Capture rate: ',float(round(df_all.frauds_captured.sum()/df_all.total_fake.sum()*100,2)))
print('False Positive rate: ',float(round((df_all.records.sum()- df_all.frauds_captured.sum())/df_all.total_posts.sum()*100,2)))
# Out:
# bad_rate_test 31.82
# Rumour  Capture rate:  38.39
# False Positive rate:  41.57

# %%
df_lstm_all=df_all.copy()
#df_lstm_all = df_lstm_all[df_lstm_all.total_posts/df_lstm_all.total_posts.max()>=0.1]
df_lstm_all['model']='LSTM'

# %% [markdown]
# #### Light GBM model

# %%
experiment = mlflow.get_experiment_by_name(f'Light GBM 2026-07-05 {event_name} run')
print(experiment.name)

if experiment is not None:
    experiment_id = experiment.experiment_id

    # Retrieve all runs in the experiment as a DataFrame
    df_han = mlflow.search_runs(experiment_ids=[experiment_id]).dropna(subset='end_time')
    
    # Show the DataFrame
    #print(df)
else:
    print(f"Experiment '{experiment_name}' not found.")
# Out:
# Light GBM 2026-07-05 sydneysiege run

# %%
dfs=[]

for run_id in list(df_han.run_id):
    try:
        path = mlflow.artifacts.download_artifacts(
            run_id=run_id,
            artifact_path=f"metrics_by_bucket_new_posts_{event_name}_LGBM.csv"
        )
        df = pd.read_csv(path)
        df["run_id"] = run_id  # track source
        #print(df.shape)
        #df["time_cut"] =df_gat[df_gat.run_id==run_id]['metrics.time_cut']

        dfs.append(df)
    except Exception:
        pass  # skip runs without the artifact

df_all = pd.concat(dfs, ignore_index=True)
df_all = df_all.merge(df_han[['run_id','metrics.time_cut']],on='run_id',how='left')
df_all.rename(columns={'Rumour s_captured':'frauds_captured'},inplace=True)

# %%
df_all.sort_values(by='metrics.time_cut',ascending=True,inplace=True)

df_all['hour']= round(df_all['metrics.time_cut']/60,2)
df_posts_by_time_cut = pd.DataFrame(df_all.groupby('metrics.time_cut')['records'].max())
df_fakes_by_time_cut = pd.DataFrame(df_all.groupby('metrics.time_cut')['frauds_captured'].max())
df_posts_by_time_cut.rename(columns={'records':'total_posts'},inplace=True)
df_fakes_by_time_cut.rename(columns={'frauds_captured':'total_fake'},inplace=True)
df_all = df_all.merge(df_posts_by_time_cut, on='metrics.time_cut',how='left')
df_all = df_all.merge(df_fakes_by_time_cut, on='metrics.time_cut',how='left')
df_all.capture_rate = round(df_all.capture_rate,3)
df_all.false_positive_rate = round(df_all.false_positive_rate,3)
df_all = df_all[df_all.total_posts<20]
df_all = df_all[(df_all['percentile']==cut)]


df_all['total_posts'] = df_all.total_posts.cumsum()
df_all['total_fake'] = df_all.total_fake.cumsum()
df_all['frauds_captured'] = df_all.frauds_captured.cumsum()
df_all['records'] = df_all.records.cumsum()
df_all['capture_rate'] = df_all['frauds_captured'] /df_all['total_fake'] 
df_all['false_positive_rate'] = (df_all['records']-df_all['frauds_captured'])/\
                    ( (df_all['records']-df_all['frauds_captured']) +  (df_all['total_posts']-df_all['records']) )


df_all['false_positive_rate'] = (df_all['records']-df_all['frauds_captured'])/\
                    ( (df_all['records']-df_all['frauds_captured']) +  (df_all['total_posts']-df_all['records']) )

df_all['false_positive_rate'] = (df_all['records']-df_all['frauds_captured'])/\
                    ( (df_all['records']-df_all['frauds_captured']) +  (df_all['total_posts']-df_all['records']) )

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Capture Rate
fig.add_trace(
    go.Scatter(
        x=df_all["hour"],
        y=df_all["capture_rate"],
        mode="lines+markers",
        name="Capture Rate",
        yaxis="y1"
    )
)

# Bad Rate
fig.add_trace(
    go.Scatter(
        x=df_all["hour"],
        y=df_all["false_positive_rate"],
        mode="lines+markers",
        name="False Positive Rate",
        yaxis="y1"
    )
)

# Total Posts (secondary axis)
fig.add_trace(
    go.Bar(
        x=df_all["hour"],
        y=df_all["total_posts"],
        name="Total Posts",
        # mode="lines+markers",
        yaxis="y2",
        opacity=1
    )
)

# Layout with dual axis
fig.update_layout(
    title="Capture Rate, FP Rate, and Total Posts by Hour",
    xaxis=dict(title="Hour"),
    yaxis=dict(title="Rates", side="left"),
    yaxis2=dict(
        title="Total Posts",
        overlaying="y",
        side="right"
    ),
    legend=dict(
        orientation="h",      # horizontal legend
        yanchor="top",
        y=-0.2,               # move below plot
        xanchor="center",
        x=0.5                 # center horizontally
    ),
    template="plotly_white"
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="a08884d4-97d6-4202-92a6-1a0b92f36946" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById
print('False Positive rate: ',float(round((df_all.records.sum()- df_all.frauds_captured.sum())/df_all.total_posts.sum()*100,2)))
# Out:
# bad_rate_test 31.82
# Rumour  Capture rate:  33.25
# False Positive rate:  42.37

# %%
df_lgbm_all=df_all.copy()
#df_lgbm_all = df_lgbm_all[df_lgbm_all.total_posts/df_lgbm_all.total_posts.max()>=0.1]
df_lgbm_all['model']='LGBM'

# %% [markdown]
# #### Random Forest model

# %%
experiment = mlflow.get_experiment_by_name(f'Random Forest 2026-07-05 {event_name} run')
print(experiment.name)

if experiment is not None:
    experiment_id = experiment.experiment_id

    # Retrieve all runs in the experiment as a DataFrame
    df_rf = mlflow.search_runs(experiment_ids=[experiment_id]).dropna(subset='end_time')
    
    # Show the DataFrame
    #print(df)
else:
    print(f"Experiment '{experiment_name}' not found.")
# Out:
# Random Forest 2026-07-05 sydneysiege run

# %%
dfs=[]

for run_id in list(df_rf.run_id):
    try:
        path = mlflow.artifacts.download_artifacts(
            run_id=run_id,
            artifact_path=f"metrics_by_bucket_new_posts_{event_name}_RF.csv"
        )
        df = pd.read_csv(path)
        df["run_id"] = run_id  # track source
        #print(df.shape)
        #df["time_cut"] =df_gat[df_gat.run_id==run_id]['metrics.time_cut']

        dfs.append(df)
    except Exception:
        pass  # skip runs without the artifact

df_all = pd.concat(dfs, ignore_index=True)
df_all = df_all.merge(df_rf[['run_id','metrics.time_cut']],on='run_id',how='left')
df_all.rename(columns={'Rumour s_captured':'frauds_captured'},inplace=True)

# %%
df_all.sort_values(by='metrics.time_cut',ascending=True,inplace=True)
df_all['hour']= round(df_all['metrics.time_cut']/60,2)
df_posts_by_time_cut = pd.DataFrame(df_all.groupby('metrics.time_cut')['records'].max())
df_fakes_by_time_cut = pd.DataFrame(df_all.groupby('metrics.time_cut')['frauds_captured'].max())
df_posts_by_time_cut.rename(columns={'records':'total_posts'},inplace=True)
df_fakes_by_time_cut.rename(columns={'frauds_captured':'total_fake'},inplace=True)
df_all = df_all.merge(df_posts_by_time_cut, on='metrics.time_cut',how='left')
df_all = df_all.merge(df_fakes_by_time_cut, on='metrics.time_cut',how='left')
df_all.capture_rate = round(df_all.capture_rate,3)
df_all.false_positive_rate = round(df_all.false_positive_rate,3)
df_all =df_all[df_all['total_posts']<=20]
df_all = df_all[(df_all['percentile']==cut)]



df_all['total_posts'] = df_all.total_posts.cumsum()
df_all['total_fake'] = df_all.total_fake.cumsum()
df_all['frauds_captured'] = df_all.frauds_captured.cumsum()
df_all['records'] = df_all.records.cumsum()
df_all['capture_rate'] = df_all['frauds_captured'] /df_all['total_fake'] 
df_all['false_positive_rate'] = (df_all['records']-df_all['frauds_captured'])/\
                    ( (df_all['records']-df_all['frauds_captured']) +  (df_all['total_posts']-df_all['records']) )


df_all['false_positive_rate'] = (df_all['records']-df_all['frauds_captured'])/\
                    ( (df_all['records']-df_all['frauds_captured']) +  (df_all['total_posts']-df_all['records']) )

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Capture Rate
fig.add_trace(
    go.Scatter(
        x=df_all["hour"],
        y=df_all["capture_rate"],
        mode="lines+markers",
        name="Capture Rate",
        yaxis="y1"
    )
)

# Bad Rate
fig.add_trace(
    go.Scatter(
        x=df_all["hour"],
        y=df_all["false_positive_rate"],
        mode="lines+markers",
        name="False Positive Rate",
        yaxis="y1"
    )
)

# Total Posts (secondary axis)
fig.add_trace(
    go.Bar(
        x=df_all["hour"],
        y=df_all["total_posts"],
        name="Total Posts",
        # mode="lines+markers",
        yaxis="y2",
        opacity=1
    )
)

# Layout with dual axis
fig.update_layout(
    title="Capture Rate, FP Rate, and Total Posts by Hour",
    xaxis=dict(title="Hour"),
    yaxis=dict(title="Rates", side="left"),
    yaxis2=dict(
        title="Total Posts",
        overlaying="y",
        side="right"
    ),
    legend=dict(
        orientation="h",      # horizontal legend
        yanchor="top",
        y=-0.2,               # move below plot
        xanchor="center",
        x=0.5                 # center horizontally
    ),
    template="plotly_white"
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="5dce0fec-2feb-4045-8123-95f11a97099b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5dce0fec-2feb-4045-8123-95f11a97099b")) {                    Plotly.newPlot(                        "5dce0fec-2feb-4045-8123-95f11a97099b",                        [{"mode":"lines+markers","name":"Capture Rate","x":{"dtype":"f8","bdata":"mpmZmZmZuT+kcD0K16PAPzMzMzMzM8M\u002fw\u002fUoXI\u002fCxT8K16NwPQrHP5qZmZmZmck\u002fcT0K16NwzT8zMzMzMzPTP3sUrkfhetQ\u002frkfhehSu1z+amZmZmZnZP4XrUbgehds\u002fzczMzMzM3D8UrkfhehTeP\u002fYoXI\u002fC9eA\u002fj8L1KFyP4j8zMzMzMzPjP9ejcD0K1+M\u002fcT0K16Nw5T8AAAAAAADoP5qZmZmZmek\u002f16NwPQrX6z9xPQrXo3DtP2ZmZmZmZu4\u002fAAAAAAAA8D97FK5H4XrwP83MzMzMzPA\u002fFK5H4XoU8j+4HoXrUbjyP+F6FK5H4fI\u002fMzMzMzMz8z+F61G4HoXzP65H4XoUrvM\u002fAAAAAAAA9D9SuB6F61H0P83MzMzMzPQ\u002f7FG4HoXr9T8UrkfhehT2P+F6FK5H4fY\u002fMzMzMzMz9z+uR+F6FK73PwAAAAAAAPg\u002fUrgehetR+D97FK5H4Xr4Px+F61G4Hvk\u002fSOF6FK5H+T+amZmZmZn5P2ZmZmZmZvo\u002f4XoUrkfh+j8zMzMzMzP7P65H4XoUrvs\u002fUrgehetR\u002fD97FK5H4Xr8P83MzMzMzPw\u002fFK5H4XoU\u002fj9mZmZmZmb+PzMzMzMzM\u002f8\u002frkfhehSu\u002fz89CtejcD0AQKRwPQrXowBAzczMzMzMAEAzMzMzMzMBQFyPwvUoXAFAcT0K16NwAUDXo3A9CtcBQAAAAAAAAAJAPQrXo3A9AkCPwvUoXI8CQArXo3A9CgNAcT0K16NwA0ApXI\u002fC9SgEQGZmZmZmZgRAj8L
AAAANY\u002fAAAAAAAA1j8AAAAAAADWP0YXXXTRRdc\u002fRhdddNFF1z9GF1100UXXP3h4eHh4eNg\u002feHh4eHh42D94eHh4eHjYP3h4eHh4eNg\u002feHh4eHh42D94eHh4eHjYP3h4eHh4eNg\u002feHh4eHh42D9YfMVXfMXXPzmO4ziO49g\u002fNpTXUF5D2T\u002f6GJyPwfnYP1PWlDVlTdk\u002fmpmZmZmZ2T+RhSxkIQvZP1VVVVVVVdk\u002fGRkZGRkZ2T+KndiJndjZP6gRlnsaYdk\u002fAAAAAAAA2T+amZmZmZnZP3h4eHh4eNg\u002fWHzFV3zF1z+9evXq1avXPwrXo3A9Ctc\u002fKMRZ+Qlx1j\u002fzwyJl4OnWP2pXonYlatc\u002fV1dXV1dX1z9GF1100UXXPxdswRZswdY\u002fF2zBFmzB1j9kIQtZyELWPwYWWGCBBdY\u002fVxCTK4jJ1T\u002ftWIEw0o7VP431obE+NNY\u002fZmZmZmZm1j\u002f29fX19fXVP57YiZ3YidU\u002fNFIxtzoj1T80UjG3OiPVP4e1b1j7htU\u002fSZIkSZIk1T\u002fDSk8tr ...

# %%
print("bad_rate_test",round(bad_rate_test*100,2))
print('Rumour  Capture rate: ',float(round(df_all.frauds_captured.sum()/df_all.total_fake.sum()*100,2)))
print('False Positive rate: ',float(round((df_all.records.sum()- df_all.frauds_captured.sum())/df_all.total_posts.sum()*100,2)))
# Out:
# bad_rate_test 31.82
# Rumour  Capture rate:  32.04
# False Positive rate:  42.11

# %%
df_rf_all=df_all.copy()
#df_rf_all = df_rf_all[df_rf_all.total_posts/df_rf_all.total_posts.max()>=0.1]
df_rf_all['model']='RF'

# %%
df_all = pd.concat([df_rf_all.iloc[-1:],df_han_all.iloc[-1:],df_gat_all.iloc[-1:],df_lgbm_all.iloc[-1:],df_lstm_all.iloc[-1:]])

TP = df_all["frauds_captured"]
FP = df_all["records"] - TP
FN = df_all["total_fake"] - TP

df_all["precision"] = TP / (TP + FP)

df_all["recall"] = df_all["capture_rate"]
df_all["f1"] = (
    2 * df_all["precision"] * df_all["recall"]
    / (df_all["precision"] + df_all["recall"])
)

result = (
    df_all.groupby("model")[
        ["recall", "precision", "f1", "capture_rate", "false_positive_rate"]
    ]
    .mean()
    .sort_values(by="f1", ascending=False)
    .round(3)
)

result
# Out:
#        recall  precision     f1  capture_rate  false_positive_rate
# model
# HAN     0.364      0.500  0.421         0.364                0.131
# LGBM    0.366      0.259  0.304         0.366                0.382
# LSTM    0.348      0.244  0.287         0.348                0.389
# RF      0.347      0.225  0.273         0.347                0.391
# GAT     0.345      0.215  0.265         0.345                0.426

# %%
df_all = pd.concat([df_rf_all,df_han_all,df_gat_all,df_lgbm_all,df_lstm_all])

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])
model_colors = {
    "RF": "#003366",      # Dark blue
    "HAN": "#D62728",     # Red
    "LGBM": "#FFD700",    # Yellow (Gold)
    "LSTM": "#5DADE2",    # Light blue
    "GAT": "#2CA02C",     # Green
}

df_all.hour = (
    df_all.hour
    - float(
        df_all.hour.min()
    )
)

# Add one line per model
for model in df_all["model"].unique():

    df_all_model = (
        df_all[df_all["model"] == model]
        .sort_values("hour")
    )

    # Capture rate lines
    fig.add_trace(
        go.Scatter(
            x=df_all_model["hour"],
            y=df_all_model["capture_rate"],
            mode="lines+markers",
            name=model,
            line=dict(
            color=model_colors.get(model, "#808080"),
            width=3,
        ),
        marker=dict(
            color=model_colors.get(model, "#808080"),
            size=3,
        )
        ),
        secondary_y=False,
    )

    # Total posts as area plot (only once)
    if model == "GAT":
        fig.add_trace(
                    go.Scatter(
            x=df_all_model["hour"],
            y=df_all_model["total_posts"],
            mode="lines",
            line=dict(color="gray", dash="dash", width=3),
            name="Total Posts",
        ),
            secondary_y=True,
        )

fig.update_layout(
    title="Rumour  Capture Rate by Model",
    template="plotly_white",
    hovermode="x unified",
        showlegend=False,
     width=900,
    height=450
)

fig.update_xaxes(title_text="hours")

fig.update_yaxes(
    title_text="Rumour  Capture Rate",
    secondary_y=False,
    tickformat=".0%",
)

fig.update_yaxes(
    title_text="Total Posts",
    secondary_y=True,
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="80191634-932d-4030-ac36-826270faba5d" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("80191634-932d-4030-ac36-826270faba5d")) {                    Plotly.newPlot(                        "80191634-932d-4030-ac36-826270faba5d",                        [{"line":{"color":"#003366","width":3},"marker":{"color":"#003366","size":3},"mode":"lines+markers","name":"RF","x":{"dtype":"f8","bdata":"AAAAAAAAAAC4HoXrUbieP5iZmZmZmak\u002f7FG4HoXrsT96FK5H4Xq0P5qZmZmZmbk\u002fpHA9CtejwD+ZmZmZmZnJPylcj8L1KMw\u002fSOF6FK5H0T80MzMzMzPTPx6F61G4HtU\u002fZmZmZmZm1j+uR+F6FK7XP4brUbgehds\u002fuB6F61G43j8AAAAAAADgP6RwPQrXo+A\u002fPgrXo3A94j\u002fNzMzMzMzkP2dmZmZmZuY\u002fpHA9Ctej6D8+CtejcD3qPzMzMzMzM+s\u002fzczMzMzM7D\u002fD9Shcj8LtP2dmZmZmZu4\u002fehSuR+F68D8ehetRuB7xP0fhehSuR\u002fE\u002fmZmZmZmZ8T\u002frUbgehevxPxSuR+F6FPI\u002fZmZmZmZm8j+4HoXrUbjyPzMzMzMzM\u002fM\u002fUrgehetR9D96FK5H4Xr0P0fhehSuR\u002fU\u002fmZmZmZmZ9T8UrkfhehT2P2ZmZmZmZvY\u002fuB6F61G49j\u002fhehSuR+H2P4XrUbgehfc\u002frkfhehSu9z8AAAAAAAD4P8zMzMzMzPg\u002fR+F6FK5H+T+ZmZmZmZn5PxSuR+F6FPo\u002fuB6F61G4+j\u002fhehSuR+H6PzMzMzMzM\u002fs\u002fehSuR+F6\u002fD\u002fMzMzMzMz8P5mZmZmZmf0\u002fFK5H4XoU\u002fj\
AAANY\u002fAAAAAAAA1j8AAAAAAADWPwAAAAAAANY\u002fAAAAAAAA1j8AAAAAAADWPwAAAAAAANY\u002fAAAAAAAA1j8AAAAAAADWP0YXXXTRRdc\u002fRhdddNFF1z9GF1100UXXP3h4eHh4eNg\u002feHh4eHh42D94eHh4eHjYP3h4eHh4eNg\u002feHh4eHh42D94eHh4eHjYP3h4eHh4eNg\u002feHh4eHh42D9YfMVXfMXXPzmO4ziO49g\u002fNpTXUF5D2T\u002f6GJyPwfnYP1PWlDVlTdk\u002fmpmZmZmZ2T+RhSxkIQvZP1VVVVVVVdk\u002fGRkZGRkZ2T+KndiJndjZP6gRlnsaYdk\u002fAAAAAAAA2T+amZmZmZnZP3h4eHh4eNg\u002fWHzFV3zF1z+9evXq1avXPwrXo3A9Ctc\u002fKMRZ+Qlx1j\u002fzwyJl4OnWP2pXonYlatc\u002fV1dXV1dX1z9GF1100UXXPxdswRZswdY\u002fF2zBFmzB1j9kIQtZyELWPwYWWGCBBdY\u002fVxCTK4jJ1T\u002ftWIEw0o7VP431obE+NNY\u002fZmZmZmZm1j\u002f29fX19fXVP57YiZ3YidU\u002fNFIxtzoj1T80UjG3OiPVP4e1b1j7htU\u002fSZIkSZIk1T\u002fDSk8tr ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])
model_colors = {
    "RF": "#003366",      # Dark blue
    "HAN": "#D62728",     # Red
    "LGBM": "#FFD700",    # Yellow (Gold)
    "LSTM": "#5DADE2",    # Light blue
    "GAT": "#2CA02C",     # Green
}



# Add one line per model
for model in df_all["model"].unique():

    df_all_model = (
        df_all[df_all["model"] == model]
        .sort_values("hour")
    )

    # Capture rate lines
    fig.add_trace(
        go.Scatter(
            x=df_all_model["hour"],
            y=df_all_model["false_positive_rate"],
            mode="lines+markers",
            name=model,
            line=dict(
            color=model_colors.get(model, "#808080"),
            width=3,
        ),
        marker=dict(
            color=model_colors.get(model, "#808080"),
            size=3,
        )
        ),
        secondary_y=False,
    )

    # Total posts as area plot (only once)
    if model == "GAT":
        fig.add_trace(
                    go.Scatter(
            x=df_all_model["hour"],
            y=df_all_model["total_posts"],
            mode="lines",
            line=dict(color="gray", dash="dash", width=3),
            name="Total Posts",
        ),
            secondary_y=True,
        )

fig.update_layout(
    title="False Positive Rate by Model",
    template="plotly_white",
    hovermode="x unified",
        legend=dict(
        orientation="h",      # horizontal legend
        yanchor="top",
        y=-0.2,               # place below the plot
        xanchor="center",
        x=0.5                 # center horizontally
    ),
    margin=dict(b=80) ,        # extra bottom margin for the legend,
     width=900,
    height=450
)

fig.update_xaxes(title_text="hours")

fig.update_yaxes(
    title_text="False Positive Rate",
    secondary_y=False,
    tickformat=".0%",
)

fig.update_yaxes(
    title_text="Total Posts",
    secondary_y=True,
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="db82a52e-5f2b-4d4c-9c53-6c44be7c99de" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById