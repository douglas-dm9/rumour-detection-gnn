# %%
import pandas as pd
from sklearn.metrics import *
from tqdm import tqdm
from utils import Hetero_Data_Processor_Filter_on_Test_since_first_post
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Usage
file_path_replies = r"replies_charlie_hebdo.pkl"
file_path_posts = r"posts_charlie_hebdo.pkl"


processor = Hetero_Data_Processor_Filter_on_Test_since_first_post(file_path_replies, file_path_posts, time_cut=20)
data = processor.process()

# %%
data
# Out:
# HeteroData(
#   id={
#     x=[1409, 106],
#     y=[1409],
#     train_mask=[1409],
#     val_mask=[1409],
#     test_mask=[1409],
#   },
#   reply_user_id={ x=[13169, 104] },
#   (id, retweet, reply_user_id)={ edge_index=[2, 13169] },
#   (reply_user_id, rev_retweet, id)={ edge_index=[2, 13169] }
# )

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv, to_hetero

class GAT(torch.nn.Module):
    def __init__(self, dim_h,dim_i, dim_out):
        super().__init__()
        self.conv1 = GATConv((-1, -1), dim_h, add_self_loops=False)
        self.conv2 = GATConv(dim_h, dim_i, add_self_loops=False)  # Added second GATConv layer
        self.linear = nn.Linear(dim_i, dim_out)
        self.dropout = nn.Dropout(p=0.4)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index).relu()
        h = self.dropout(h)
        h = self.conv2(h, edge_index).relu()  # Pass through the second GATConv layer
        h = self.dropout(h)
        h = self.linear(h)
        return h

# %%
model = GAT(dim_h=64,dim_i=32, dim_out=2)
model = to_hetero(model, data.metadata(), aggr='sum')

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
data, model = data.to(device), model.to(device)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
import torch
from torch.nn.functional import cross_entropy

def evaluate(model, data, mask_names):
    model.eval()
    out = model(data.x_dict, data.edge_index_dict)
    preds = out.argmax(dim=-1)
    labels = data['id'].y

    if isinstance(mask_names, str):
        mask = data['id'][mask_names]
    else:
        mask = torch.zeros_like(data['id'].y, dtype=torch.bool)
        for name in mask_names:
            mask |= data['id'][name]

    preds_masked = preds[mask]
    labels_masked = labels[mask]
    probs = out[mask][:, 1]  # Fixed: out is a tensor

    acc = accuracy_score(labels_masked.cpu(), preds_masked.cpu())
    precision = precision_score(labels_masked.cpu(), preds_masked.cpu(), zero_division=0)
    recall = recall_score(labels_masked.cpu(), preds_masked.cpu(), zero_division=0)

    try:
        auc = roc_auc_score(labels_masked.cpu(), probs.detach().cpu())
    except ValueError:
        auc = 0.0

    return acc, precision, recall, auc


def evaluate_metrics(model, data, mask):
    model.eval()
    with torch.no_grad():
        out = model(data.x_dict, data.edge_index_dict)['id']
        preds = out.argmax(dim=1)
        probs = out[:, 1]  # Probability of class 1

    true = data['id'].y[mask]
    pred = preds[mask]
    prob = probs[mask]

    acc = accuracy_score(true.cpu(), pred.cpu())
    prec = precision_score(true.cpu(), pred.cpu(), average='macro', zero_division=0)
    recall = recall_score(true.cpu(), pred.cpu(), average='macro', zero_division=0)
    try:
        auc = roc_auc_score(true.cpu(), prob.cpu())
    except:
        auc = 0.0

    return acc, prec, recall, auc

# %%
y_train = data['id'].y[data['id'].train_mask].cpu()
imbalance = (y_train == 1).sum() / len(y_train)

for epoch in range(1, 101):
            model.train()
            optimizer.zero_grad()
            out = model(data.x_dict, data.edge_index_dict)['id']
            mask = data['id'].train_mask
            loss = F.cross_entropy(out[mask], data['id'].y[mask])
            loss.backward()
            optimizer.step()

            if epoch % 100 == 0:
                 train_acc, train_prec, train_recall, train_auc= evaluate_metrics(model, data, data['id'].train_mask)
                 print(f"[Epoch {epoch}] Train Loss: {loss:.4f} | Train Recall: {train_recall:.4f} | Train Auc: {train_auc:.4f}")

# Final evaluation on val + test
final_mask = data['id'].val_mask | data['id'].test_mask
acc, prec, recall, auc = evaluate_metrics(model, data, final_mask)
print(f"[Final Val+Test] Acc: {acc:.4f} | Prec: {prec:.4f} | Recall: {recall:.4f} | AUC: {auc:.4f}")
# Out:
# [Epoch 100] Train Loss: 0.3127 | Train Recall: 0.7934 | Train Auc: 0.9169
# [Final Val+Test] Acc: 0.6250 | Prec: 0.7857 | Recall: 0.6250 | AUC: 0.8750

# %% [markdown]
# #### Training Draft Model

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
#mlflow.set_experiment("spyder-experiment")
import mlflow.pytorch
mlflow.set_experiment("GAT Network 2025-06-07  Charlie Hebdo")

# %%
def evaluate_metrics(model, data, mask):
    model.eval()
    with torch.no_grad():
        out = model(data.x_dict, data.edge_index_dict)['id']
        preds = out.argmax(dim=1)
        probs = out[:, 1]  # Probability of class 1

    true = data['id'].y[mask]
    pred = preds[mask]
    prob = probs[mask]

    acc = accuracy_score(true.cpu(), pred.cpu())
    prec = precision_score(true.cpu(), pred.cpu(), average='macro', zero_division=0)
    recall = recall_score(true.cpu(), pred.cpu(), average='macro', zero_division=0)
    try:
        auc = roc_auc_score(true.cpu(), prob.cpu())
    except:
        auc = 0.0

    return acc, prec, recall, auc

for time_cut in range(20, (60 * 24 * 3), 15):
    print(f"\n=== Time Cut: {time_cut} ===")
    processor = Hetero_Data_Processor_Filter_on_Test_since_first_post(file_path_replies, file_path_posts, time_cut=time_cut)
    data = processor.process()

    model = GAT(dim_h=64, dim_i=32, dim_out=2)
    model = to_hetero(model, data.metadata(), aggr='sum')
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    data, model = data.to(device), model.to(device)

    # Compute imbalance
    y_train = data['id'].y[data['id'].train_mask].cpu()
    imbalance = (y_train == 1).sum() / len(y_train)

    with mlflow.start_run(run_name=f"time_cut_{time_cut}"):
        for epoch in range(1, 101):
            model.train()
            optimizer.zero_grad()
            out = model(data.x_dict, data.edge_index_dict)['id']
            mask = data['id'].train_mask
            loss = F.cross_entropy(out[mask], data['id'].y[mask])
            loss.backward()
            optimizer.step()

            if epoch % 100 == 0:
                 train_acc, train_prec, train_recall, train_auc= evaluate_metrics(model, data, data['id'].train_mask)
                 print(f"[Epoch {epoch}] Train Loss: {loss:.4f} | Train Recall: {train_recall:.4f} | Train Auc: {train_auc:.4f}")
        mlflow.log_metric("train_recall", train_recall, step=epoch)
        mlflow.log_metric("train_precision", train_prec, step=epoch)
        mlflow.log_metric("train_auc", train_auc, step=epoch)

        # Final evaluation on val + test
        final_mask = data['id'].val_mask | data['id'].test_mask
        acc, prec, recall, auc = evaluate_metrics(model, data, final_mask)
        print(f"[Final Val+Test] Acc: {acc:.4f} | Prec: {prec:.4f} | Recall: {recall:.4f} | AUC: {auc:.4f}")

        mlflow.log_metric("final_acc", acc)
        mlflow.log_metric("final_precision", prec)
        mlflow.log_metric("final_recall", recall)
        mlflow.log_metric("final_auc", auc)
        mlflow.log_metric("train_imbalance_rate", imbalance.item())

        mlflow.log_metric("time_cut", time_cut)
# Out:
# === Time Cut: 20 ===
# [Epoch 100] Train Loss: 0.3251 | Train Recall: 0.8056 | Train Auc: 0.9113
# [Final Val+Test] Acc: 0.7500 | Prec: 0.8333 | Recall: 0.7500 | AUC: 0.8750
#
# === Time Cut: 35 ===
# [Epoch 100] Train Loss: 0.3272 | Train Recall: 0.7606 | Train Auc: 0.9146
# [Final Val+Test] Acc: 0.6800 | Prec: 0.7316 | Recall: 0.7045 | AUC: 0.8636
#
# === Time Cut: 50 ===
# [Epoch 100] Train Loss: 0.3174 | Train Recall: 0.8244 | Train Auc: 0.9094
# [Final Val+Test] Acc: 0.7273 | Prec: 0.7481 | Recall: 0.7389 | AUC: 0.8889
#
# === Time Cut: 65 ===
# [Epoch 100] Train Loss: 0.3488 | Train Recall: 0.7990 | Train Auc: 0.8958
# [Final Val+Test] Acc: 0.7073 | Prec: 0.7712 | Recall: 0.7131 | AUC: 0.9024
#
# === Time Cut: 80 ===
# [Epoch 100] Train Loss: 0.3673 | Train Recall: 0.7361 | Train Auc: 0.8826
# [Final Val+Test] Acc: 0.6136 | Prec: 0.7153 | Recall: 0.6284 | AUC: 0.9089
#
# === Time Cut: 95 ===
# [Epoch 100] Train Loss: 0.3231 | Train Recall: 0.8015 | Train Auc: 0.9160
# [Final Val+Test] Acc: 0.7368 | Prec: 0.7632 | Recall: 0.7340 | AUC: 0.8756
#
# === Time Cut: 110 ===
# [Epoch 100] Train Loss: 0.3423 | Train Recall: 0.7879 | Train Auc: 0.8982
# [Final Val+Test] Acc: 0.7606 | Prec: 0.8029 | Recall: 0.7331 | AUC: 0.9016
#
# === Time Cut: 125 ===
# [Epoch 100] Train Loss: 0.3619 | Train Recall: 0.7436 | Train Auc: 0.8824
# [Final Val+Test] Acc: 0.7229 | Prec: 0.7688 | Recall: 0.6421 | AUC: 0.8809
#
# === Time Cut: 140 ===
# [Epoch 100] Train Loss: 0.3159 | Train Recall: 0.8253 | Train Auc: 0.9132
# [Final Val+Test] Acc: 0.7778 | Prec: 0.7597 | Recall: 0.7052 | AUC: 0.8988
#
# === Time Cut: 155 ===
# [Epoch 100] Train Loss: 0.3319 | Train Recall: 0.7742 | Train Auc: 0.9014
# [Final Val+Test] Acc: 0.7611 | Prec: 0.7175 | Recall: 0.6532 | AUC: 0.8746
#
# === Time Cut: 170 ===
# [Epoch 100] Train Loss: 0.3310 | Train Recall: 0.7966 | Train Auc: 0.9014
# [Final Val+Test] Acc: 0.7984 | Prec: 0.7668 | Recall: 0.6695 | AUC: 0.8958
#
# === Time Cut: 185 ===
# [Epoch 100] Train Loss: 0.3473 | Train Recall: 0.7655 | Train Auc: 0.8964
# [Final Val+Test] Acc: 0.7769 | Prec: 0.7045 | Recall: 0.6406 | AUC: 0.8828
#
# === Time Cut: 200 ===
# [Epoch 100] Train Loss: 0.3209 | Train Recall: 0.7948 | Train Auc: 0.9078
# [Final Val+Test] Acc: 0.8252 | Prec: 0.7851 | Recall: 0.7008 | AUC: 0.9146
#
# === Time Cut: 215 ===
# [Epoch 100] Train Loss: 0.3170 | Train Recall: 0.8217 | Train Auc: 0.9168
# [Final Val+Test] Acc: 0.8519 | Prec: 0.7932 | Recall: 0.7560 | AUC: 0.9098
#
# === Time Cut: 230 ===
# [Epoch 100] Train Loss: 0.3614 | Train Recall: 0.7379 | Train Auc: 0.8890
# [Final Val+Test] Acc: 0.8132 | Prec: 0.7024 | Recall: 0.5906 | AUC: 0.8917
#
# === Time Cut: 245 ===
# [Epoch 100] Train Loss: 0.3583 | Train Recall: 0.7641 | Train Auc: 0.8914
# [Final Val+Test] Acc: 0.8639 | Prec: 0.8045 | Recall: 0.7029 | AUC: 0.9070
#
# === Time Cut: 260 ===
# [Epoch 100] Train Loss: 0.3262 | Train Recall: 0.7788 | Train Auc: 0.9100
# [Final Val+Test] Acc: 0.8693 | Prec: 0.7999 | Recall: 0.7146 | AUC: 0.9018
#
# === Time Cut: 275 ===
# [Epoch 100] Train Loss: 0.3299 | Train Recall: 0.7767 | Train Auc: 0.9062
# [Final Val+Test] Acc: 0.8632 | Prec: 0.7635 | Recall: 0.7077 | AUC: 0.9132
#
# === Time Cut: 290 ===
# [Epoch 100] Train Loss: 0.3333 | Train Recall: 0.7954 | Train Auc: 0.9046
# [Final Val+Test] Acc: 0.8679 | Prec: 0.7801 | Recall: 0.6995 | AUC: 0.9198
#
# === Time Cut: 305 ===
# [Epoch 100] Train Loss: 0.3542 | Train Recall: 0.7687 | Train Auc: 0.8863
# [Final Val+Test] Acc: 0.8538 | Prec: 0.7461 | Recall: 0.6689 | AUC: 0.8999
#
# === Time Cut: 320 ===
# [Epoch 100] Train Loss: 0.3536 | Train Recall: 0.7562 | Train Auc: 0.8884
# [Final Val+Test] Acc: 0.8645 | Prec: 0.7831 | Recall: 0.6637 | AUC: 0.8987
#
# === Time Cut: 335 ===
# [Epoch 100] Train Loss: 0.3490 | Train Recall: 0.7849 | Train Auc: 0.8990
# [Final Val+Test] Acc: 0.8505 | Prec: 0.7320 | Recall: 0.6885 | AUC: 0.9139
#
# === Time Cut: 350 ===
# [Epoch 100] Train Loss: 0.3683 | Train Recall: 0.7274 | Train Auc: 0.8868
# [Final Val+Test] Acc: 0.8605 | Prec: 0.7660 | Recall: 0.6610 | AUC: 0.9011
#
# === Time Cut: 365 ===
# [Epoch 100] Train Loss: 0.2907 | Train Recall: 0.8229 | Train Auc: 0.9315
# [Final Val+Test] Acc: 0.8837 | Prec: 0.7979 | Recall: 0.7637 | AUC: 0.9109
#
# === Time Cut: 380 ===
# [Epoch 100] Train Loss: 0.3251 | Train Recall: 0.7642 | Train Auc: 0.9090
# [Final Val+Test] Acc: 0.8744 | Prec: 0.8030 | Recall: 0.6916 | AUC: 0.8934
#
# === Time Cut: 395 ===
# [Epoch 100] Train Loss: 0.3153 | Train Recall: 0.8148 | Train Auc: 0.9158
# [Final Val+Test] Acc: 0.8744 | Prec: 0.7855 | Recall: 0.7249 | AUC: 0.9280
#
# === Time Cut: 410 ===
# [Epoch 100] Train Loss: 0.3269 | Train Recall: 0.7911 | Train Auc: 0.9127
# [Final Val+Test] Acc: 0.8657 | Prec: 0.7717 | Recall: 0.6861 | AUC: 0.8910
#
# === Time Cut: 425 ===
# [Epoch 100] Train Loss: 0.3420 | Train Recall: 0.7590 | Train Auc: 0.9037
# [Final Val+Test] Acc: 0.8611 | Prec: 0.7727 | Recall: 0.6500 | AUC: 0.9049
#
# === Time Cut: 440 ===
# [Epoch 100] Train Loss: 0.3381 | Train Recall: 0.7396 | Train Auc: 0.8958
# [Final Val+Test] Acc: 0.8565 | Prec: 0.7549 | Recall: 0.6472 | AUC: 0.9111
#
# === Time Cut: 455 ===
# [Epoch 100] Train Loss: 0.3435 | Train Recall: 0.7502 | Train Auc: 0.8953
# [Final Val+Test] Acc: 0.8611 | Prec: 0.7663 | Recall: 0.6611 | AUC: 0.9216
#
# === Time Cut: 470 ===
# [Epoch 100] Train Loss: 0.3024 | Train Recall: 0.8177 | Train Auc: 0.9136
# [Final Val+Test] Acc: 0.8889 | Prec: 0.8025 | Recall: 0.7889 | AUC: 0.9244
#
# === Time Cut: 485 ===
# [Epoch 100] Train Loss: 0.3307 | Train Recall: 0.7986 | Train Auc: 0.9142
# [Final Val+Test] Acc: 0.8657 | Prec: 0.7622 | Recall: 0.7194 | AUC: 0.9179
#
# === Time Cut: 500 ===
# [Epoch 100] Train Loss: 0.3647 | Train Recall: 0.7290 | Train Auc: 0.8824
# [Final Val+Test] Acc: 0.8611 | Prec: 0.7727 | Recall: 0.6500 | AUC: 0.9023
#
# === Time Cut: 515 ===
# [Epoch 100] Train Loss: 0.3646 | Train Recall: 0.7719 | Train Auc: 0.8972
# [Final Val+Test] Acc: 0.8664 | Prec: 0.7720 | Recall: 0.6862 | AUC: 0.9203
#
# === Time Cut: 530 ===
# [Epoch 100] Train Loss: 0.3344 | Train Recall: 0.8032 | Train Auc: 0.9052
# [Final Val+Test] Acc: 0.8756 | Prec: 0.7824 | Recall: 0.7363 | AUC: 0.9207
#
# === Time Cut: 545 ===
# [Epoch 100] Train Loss: 0.3318 | Train Recall: 0.8052 | Train Auc: 0.9091
# [Final Val+Test] Acc: 0.8802 | Prec: 0.8049 | Recall: 0.7168 | AUC: 0.9276
#
# === Time Cut: 560 ===
# [Epoch 100] Train Loss: 0.3525 | Train Recall: 0.7669 | Train Auc: 0.8998
# [Final Val+Test] Acc: 0.8710 | Prec: 0.7815 | Recall: 0.7001 | AUC: 0.9127
#
# === Time Cut: 575 ===
# [Epoch 100] Train Loss: 0.3389 | Train Recall: 0.7933 | Train Auc: 0.8987
#
# === Time Cut: 785 ===
# [Epoch 100] Train Loss: 0.3379 | Train Recall: 0.7785 | Train Auc: 0.9004
# [Final Val+Test] Acc: 0.8604 | Prec: 0.7541 | Recall: 0.6892 | AUC: 0.9008
#
# === Time Cut: 800 ===
# [Epoch 100] Train Loss: 0.3548 | Train Recall: 0.7491 | Train Auc: 0.8941
# [Final Val+Test] Acc: 0.8565 | Prec: 0.7439 | Recall: 0.6713 | AUC: 0.8975
#
# === Time Cut: 815 ===
# [Epoch 100] Train Loss: 0.3310 | Train Recall: 0.7984 | Train Auc: 0.9081
# [Final Val+Test] Acc: 0.8766 | Prec: 0.7963 | Recall: 0.7269 | AUC: 0.8914
#
# === Time Cut: 830 ===
# [Epoch 100] Train Loss: 0.3507 | Train Recall: 0.7537 | Train Auc: 0.8946
# [Final Val+Test] Acc: 0.8511 | Prec: 0.7430 | Recall: 0.6519 | AUC: 0.8859
#
# === Time Cut: 845 ===
# [Epoch 100] Train Loss: 0.3248 | Train Recall: 0.7988 | Train Auc: 0.9062
# [Final Val+Test] Acc: 0.8739 | Prec: 0.7997 | Recall: 0.7418 | AUC: 0.9104
#
# === Time Cut: 860 ===
# [Epoch 100] Train Loss: 0.3251 | Train Recall: 0.8002 | Train Auc: 0.9086
# [Final Val+Test] Acc: 0.8529 | Prec: 0.7619 | Recall: 0.6837 | AUC: 0.9061
#
# === Time Cut: 875 ===
# [Epoch 100] Train Loss: 0.3735 | Train Recall: 0.7167 | Train Auc: 0.8777
# [Final Val+Test] Acc: 0.8410 | Prec: 0.7453 | Recall: 0.6217 | AUC: 0.8747
#
# === Time Cut: 890 ===
# [Epoch 100] Train Loss: 0.3579 | Train Recall: 0.7730 | Train Auc: 0.8960
# [Final Val+Test] Acc: 0.8536 | Prec: 0.7593 | Recall: 0.6929 | AUC: 0.8778
#
# === Time Cut: 905 ===
# [Epoch 100] Train Loss: 0.3499 | Train Recall: 0.7838 | Train Auc: 0.8901
# [Final Val+Test] Acc: 0.8536 | Prec: 0.7659 | Recall: 0.6747 | AUC: 0.8962
#
# === Time Cut: 920 ===
# [Epoch 100] Train Loss: 0.3317 | Train Recall: 0.8036 | Train Auc: 0.9084
# [Final Val+Test] Acc: 0.8619 | Prec: 0.7750 | Recall: 0.7161 | AUC: 0.9078
#
# === Time Cut: 935 ===
# [Epoch 100] Train Loss: 0.3288 | Train Recall: 0.7974 | Train Auc: 0.9078
# [Final Val+Test] Acc: 0.8458 | Prec: 0.7466 | Recall: 0.6853 | AUC: 0.8962
#
# === Time Cut: 950 ===
# [Epoch 100] Train Loss: 0.3097 | Train Recall: 0.7884 | Train Auc: 0.9167
# [Final Val+Test] Acc: 0.8458 | Prec: 0.7514 | Recall: 0.6677 | AUC: 0.8937
#
# === Time Cut: 965 ===
# [Epoch 100] Train Loss: 0.3579 | Train Recall: 0.7480 | Train Auc: 0.8901
# [Final Val+Test] Acc: 0.8458 | Prec: 0.7812 | Recall: 0.6236 | AUC: 0.8706
#
# === Time Cut: 980 ===
# [Epoch 100] Train Loss: 0.3184 | Train Recall: 0.8018 | Train Auc: 0.9200
# [Final Val+Test] Acc: 0.8667 | Prec: 0.8005 | Recall: 0.7069 | AUC: 0.9100
#
# === Time Cut: 995 ===
# [Epoch 100] Train Loss: 0.3421 | Train Recall: 0.7605 | Train Auc: 0.8933
# [Final Val+Test] Acc: 0.8583 | Prec: 0.7994 | Recall: 0.6665 | AUC: 0.8653
#
# === Time Cut: 1010 ===
# [Epoch 100] Train Loss: 0.3256 | Train Recall: 0.7938 | Train Auc: 0.9098
# [Final Val+Test] Acc: 0.8625 | Prec: 0.7880 | Recall: 0.7043 | AUC: 0.8962
#
# === Time Cut: 1025 ===
# [Epoch 100] Train Loss: 0.3351 | Train Recall: 0.8002 | Train Auc: 0.9050
# [Final Val+Test] Acc: 0.8458 | Prec: 0.7487 | Recall: 0.6765 | AUC: 0.8917
#
# === Time Cut: 1040 ===
# [Epoch 100] Train Loss: 0.3578 | Train Recall: 0.7427 | Train Auc: 0.8858
# [Final Val+Test] Acc: 0.8500 | Prec: 0.7913 | Recall: 0.6350 | AUC: 0.8574
#
# === Time Cut: 1055 ===
# [Epoch 100] Train Loss: 0.3389 | Train Recall: 0.7801 | Train Auc: 0.8965
# [Final Val+Test] Acc: 0.8542 | Prec: 0.7683 | Recall: 0.6904 | AUC: 0.8832
#
# === Time Cut: 1070 ===
# [Epoch 100] Train Loss: 0.3276 | Train Recall: 0.7721 | Train Auc: 0.9047
# [Final Val+Test] Acc: 0.8542 | Prec: 0.7772 | Recall: 0.6728 | AUC: 0.8961
#
# === Time Cut: 1085 ===
# [Epoch 100] Train Loss: 0.3144 | Train Recall: 0.8022 | Train Auc: 0.9175
# [Final Val+Test] Acc: 0.8458 | Prec: 0.7487 | Recall: 0.6765 | AUC: 0.8977
#
# === Time Cut: 1100 ===
# [Epoch 100] Train Loss: 0.3132 | Train Recall: 0.8372 | Train Auc: 0.9179
# [Final Val+Test] Acc: 0.8625 | Prec: 0.7802 | Recall: 0.7219 | AUC: 0.9099
#
# === Time Cut: 1115 ===
# [Epoch 100] Train Loss: 0.3369 | Train Recall: 0.8141 | Train Auc: 0.9066
# [Final Val+Test] Acc: 0.8500 | Prec: 0.7548 | Recall: 0.6967 | AUC: 0.8915
#
# === Time Cut: 1130 ===
# [Epoch 100] Train Loss: 0.3292 | Train Recall: 0.7870 | Train Auc: 0.9136
# [Final Val+Test] Acc: 0.8542 | Prec: 0.7772 | Recall: 0.6728 | AUC: 0.8948
#
# === Time Cut: 1145 ===
# [Epoch 100] Train Loss: 0.3750 | Train Recall: 0.7648 | Train Auc: 0.8837
# [Final Val+Test] Acc: 0.8500 | Prec: 0.7601 | Recall: 0.6790 | AUC: 0.8806
#
# === Time Cut: 1160 ===
# [Epoch 100] Train Loss: 0.3636 | Train Recall: 0.7537 | Train Auc: 0.8937
# [Final Val+Test] Acc: 0.8458 | Prec: 0.7593 | Recall: 0.6500 | AUC: 0.8715
#
# === Time Cut: 1175 ===
# [Final Val+Test] Acc: 0.8533 | Prec: 0.7366 | Recall: 0.7194 | AUC: 0.8871
#
# === Time Cut: 1580 ===
# [Epoch 100] Train Loss: 0.3009 | Train Recall: 0.8329 | Train Auc: 0.9250
# [Final Val+Test] Acc: 0.8754 | Prec: 0.7835 | Recall: 0.7322 | AUC: 0.9075
#
# === Time Cut: 1595 ===
# [Epoch 100] Train Loss: 0.3438 | Train Recall: 0.7863 | Train Auc: 0.9001
# [Final Val+Test] Acc: 0.8647 | Prec: 0.7620 | Recall: 0.7156 | AUC: 0.8650
#
# === Time Cut: 1610 ===
# [Epoch 100] Train Loss: 0.3445 | Train Recall: 0.7922 | Train Auc: 0.9025
# [Final Val+Test] Acc: 0.8523 | Prec: 0.7305 | Recall: 0.6832 | AUC: 0.8757
#
# === Time Cut: 1625 ===
# [Epoch 100] Train Loss: 0.3239 | Train Recall: 0.8064 | Train Auc: 0.9115
# [Final Val+Test] Acc: 0.8531 | Prec: 0.7307 | Recall: 0.6904 | AUC: 0.8670
#
# === Time Cut: 1640 ===
# [Epoch 100] Train Loss: 0.3818 | Train Recall: 0.7726 | Train Auc: 0.9030
# [Final Val+Test] Acc: 0.8687 | Prec: 0.7647 | Recall: 0.7061 | AUC: 0.8757
#
# === Time Cut: 1655 ===
# [Epoch 100] Train Loss: 0.3484 | Train Recall: 0.7876 | Train Auc: 0.9023
# [Final Val+Test] Acc: 0.8595 | Prec: 0.7430 | Recall: 0.6976 | AUC: 0.8685
#
# === Time Cut: 1670 ===
# [Epoch 100] Train Loss: 0.3524 | Train Recall: 0.7982 | Train Auc: 0.9045
# [Final Val+Test] Acc: 0.8638 | Prec: 0.7482 | Recall: 0.7201 | AUC: 0.8791
#
# === Time Cut: 1685 ===
# [Epoch 100] Train Loss: 0.3435 | Train Recall: 0.8002 | Train Auc: 0.9045
# [Final Val+Test] Acc: 0.8625 | Prec: 0.7450 | Recall: 0.6915 | AUC: 0.8543
#
# === Time Cut: 1700 ===
# [Epoch 100] Train Loss: 0.3354 | Train Recall: 0.7879 | Train Auc: 0.9073
# [Final Val+Test] Acc: 0.8621 | Prec: 0.7385 | Recall: 0.7043 | AUC: 0.8924
#
# === Time Cut: 1715 ===
# [Epoch 100] Train Loss: 0.3250 | Train Recall: 0.8150 | Train Auc: 0.9155
# [Final Val+Test] Acc: 0.8661 | Prec: 0.7457 | Recall: 0.6993 | AUC: 0.8690
#
# === Time Cut: 1730 ===
# [Epoch 100] Train Loss: 0.3159 | Train Recall: 0.8046 | Train Auc: 0.9100
# [Final Val+Test] Acc: 0.8711 | Prec: 0.7511 | Recall: 0.7223 | AUC: 0.8831
#
# === Time Cut: 1745 ===
# [Epoch 100] Train Loss: 0.3585 | Train Recall: 0.7555 | Train Auc: 0.8987
# [Final Val+Test] Acc: 0.8629 | Prec: 0.7292 | Recall: 0.6750 | AUC: 0.8698
#
# === Time Cut: 1760 ===
# [Epoch 100] Train Loss: 0.3238 | Train Recall: 0.8269 | Train Auc: 0.9158
# [Final Val+Test] Acc: 0.8471 | Prec: 0.7770 | Recall: 0.7458 | AUC: 0.8818
#
# === Time Cut: 3155 ===
# [Epoch 100] Train Loss: 0.3669 | Train Recall: 0.7573 | Train Auc: 0.8855
# [Final Val+Test] Acc: 0.8462 | Prec: 0.7770 | Recall: 0.7484 | AUC: 0.8772
#
# === Time Cut: 3170 ===
# [Epoch 100] Train Loss: 0.3108 | Train Recall: 0.8059 | Train Auc: 0.9131
# [Final Val+Test] Acc: 0.8467 | Prec: 0.7749 | Recall: 0.7715 | AUC: 0.8994
#
# === Time Cut: 3185 ===
# [Epoch 100] Train Loss: 0.3625 | Train Recall: 0.7359 | Train Auc: 0.8876
# [Final Val+Test] Acc: 0.8310 | Prec: 0.7497 | Recall: 0.7225 | AUC: 0.8714
#
# === Time Cut: 3200 ===
# [Epoch 100] Train Loss: 0.3456 | Train Recall: 0.7735 | Train Auc: 0.8988
# [Final Val+Test] Acc: 0.8296 | Prec: 0.7557 | Recall: 0.7441 | AUC: 0.8736
#
# === Time Cut: 3215 ===
# [Epoch 100] Train Loss: 0.3591 | Train Recall: 0.7245 | Train Auc: 0.8981
# [Final Val+Test] Acc: 0.8094 | Prec: 0.7247 | Recall: 0.7047 | AUC: 0.8558
#
# === Time Cut: 3230 ===
# [Epoch 100] Train Loss: 0.3580 | Train Recall: 0.7464 | Train Auc: 0.8919
# [Final Val+Test] Acc: 0.8110 | Prec: 0.7282 | Recall: 0.7270 | AUC: 0.8559
#
# === Time Cut: 3245 ===
# [Epoch 100] Train Loss: 0.3462 | Train Recall: 0.7788 | Train Auc: 0.8967
# [Final Val+Test] Acc: 0.8094 | Prec: 0.7278 | Recall: 0.7418 | AUC: 0.8662
#
# === Time Cut: 3260 ===
# [Epoch 100] Train Loss: 0.3773 | Train Recall: 0.7185 | Train Auc: 0.8844
# [Final Val+Test] Acc: 0.7963 | Prec: 0.7047 | Recall: 0.6935 | AUC: 0.8431
#
# === Time Cut: 3275 ===
# [Epoch 100] Train Loss: 0.3329 | Train Recall: 0.7774 | Train Auc: 0.9037
# [Final Val+Test] Acc: 0.8180 | Prec: 0.7397 | Recall: 0.7580 | AUC: 0.8699
#
# === Time Cut: 3290 ===
# [Epoch 100] Train Loss: 0.3471 | Train Recall: 0.7738 | Train Auc: 0.8975
# [Final Val+Test] Acc: 0.8030 | Prec: 0.7180 | Recall: 0.7270 | AUC: 0.8576
#
# === Time Cut: 3305 ===
# [Epoch 100] Train Loss: 0.3338 | Train Recall: 0.7743 | Train Auc: 0.9066
# [Final Val+Test] Acc: 0.8214 | Prec: 0.7430 | Recall: 0.7468 | AUC: 0.8758
#
# === Time Cut: 3320 ===
# [Epoch 100] Train Loss: 0.3370 | Train Recall: 0.7884 | Train Auc: 0.9022
# [Final Val+Test] Acc: 0.8114 | Prec: 0.7297 | Recall: 0.7404 | AUC: 0.8642
#
# === Time Cut: 3335 ===
# [Epoch 100] Train Loss: 0.3174 | Train Recall: 0.8157 | Train Auc: 0.9080
# [Final Val+Test] Acc: 0.8267 | Prec: 0.7505 | Recall: 0.7395 | AUC: 0.8715
#
# === Time Cut: 3545 ===
# [Epoch 100] Train Loss: 0.3270 | Train Recall: 0.7936 | Train Auc: 0.9075
# [Final Val+Test] Acc: 0.8200 | Prec: 0.7412 | Recall: 0.7512 | AUC: 0.8771
#
# === Time Cut: 3560 ===
# [Epoch 100] Train Loss: 0.3684 | Train Recall: 0.7122 | Train Auc: 0.8724
# [Final Val+Test] Acc: 0.8000 | Prec: 0.7087 | Recall: 0.6852 | AUC: 0.8568
#
# === Time Cut: 3575 ===
# [Epoch 100] Train Loss: 0.3792 | Train Recall: 0.7311 | Train Auc: 0.8802
# [Final Val+Test] Acc: 0.8017 | Prec: 0.7129 | Recall: 0.7048 | AUC: 0.8439
#
# === Time Cut: 3590 ===
# [Epoch 100] Train Loss: 0.3671 | Train Recall: 0.8075 | Train Auc: 0.8969
# [Final Val+Test] Acc: 0.8133 | Prec: 0.7341 | Recall: 0.7575 | AUC: 0.8648
#
# === Time Cut: 3605 ===
# [Epoch 100] Train Loss: 0.3481 | Train Recall: 0.7890 | Train Auc: 0.8998
# [Final Val+Test] Acc: 0.8067 | Prec: 0.7254 | Recall: 0.7479 | AUC: 0.8711
#
# === Time Cut: 3620 ===
# [Epoch 100] Train Loss: 0.3109 | Train Recall: 0.8367 | Train Auc: 0.9106
# [Final Val+Test] Acc: 0.8167 | Prec: 0.7412 | Recall: 0.7783 | AUC: 0.8672
#
# === Time Cut: 3635 ===
# [Epoch 100] Train Loss: 0.3225 | Train Recall: 0.7626 | Train Auc: 0.9158
# [Final Val+Test] Acc: 0.8267 | Prec: 0.7510 | Recall: 0.7316 | AUC: 0.8796
#
# === Time Cut: 3650 ===
# [Epoch 100] Train Loss: 0.3632 | Train Recall: 0.7685 | Train Auc: 0.8908
# [Final Val+Test] Acc: 0.8103 | Prec: 0.7286 | Recall: 0.7449 | AUC: 0.8472
#
# === Time Cut: 3665 ===
# [Epoch 100] Train Loss: 0.3307 | Train Recall: 0.8091 | Train Auc: 0.9043
# [Final Val+Test] Acc: 0.8170 | Prec: 0.7399 | Recall: 0.7705 | AUC: 0.8706
#
# === Time Cut: 3680 ===
# [Epoch 100] Train Loss: 0.3392 | Train Recall: 0.7977 | Train Auc: 0.8993
# [Final Val+Test] Acc: 0.8070 | Prec: 0.7260 | Recall: 0.7508 | AUC: 0.8635
#
# === Time Cut: 3695 ===
# [Epoch 100] Train Loss: 0.3348 | Train Recall: 0.7727 | Train Auc: 0.9048
# [Final Val+Test] Acc: 0.8203 | Prec: 0.7411 | Recall: 0.7487 | AUC: 0.8593
#
# === Time Cut: 3710 ===
# [Epoch 100] Train Loss: 0.3529 | Train Recall: 0.7698 | Train Auc: 0.8929
# [Final Val+Test] Acc: 0.8087 | Prec: 0.7266 | Recall: 0.7438 | AUC: 0.8653
#
# === Time Cut: 3725 ===
# [Epoch 100] Train Loss: 0.3582 | Train Recall: 0.7543 | Train Auc: 0.8689
# [Final Val+Test] Acc: 0.8003 | Prec: 0.7127 | Recall: 0.7172 | AUC: 0.8312
#
# === Time Cut: 3740 ===
# [Epoch 100] Train Loss: 0.3235 | Train Recall: 0.8080 | Train Auc: 0.9131
# [Final Val+Test] Acc: 0.8170 | Prec: 0.7390 | Recall: 0.7652 | AUC: 0.8757
#
# === Time Cut: 3755 ===
# [Epoch 100] Train Loss: 0.3236 | Train Recall: 0.8107 | Train Auc: 0.9079
# [Final Val+Test] Acc: 0.8186 | Prec: 0.7410 | Recall: 0.7662 | AUC: 0.8783
#
# === Time Cut: 3770 ===
# [Epoch 100] Train Loss: 0.3116 | Train Recall: 0.8025 | Train Auc: 0.9093
# [Final Val+Test] Acc: 0.8203 | Prec: 0.7413 | Recall: 0.7513 | AUC: 0.8674
#
# === Time Cut: 3785 ===
# [Epoch 100] Train Loss: 0.3253 | Train Recall: 0.7948 | Train Auc: 0.9131
# [Final Val+Test] Acc: 0.8220 | Prec: 0.7435 | Recall: 0.7524 | AUC: 0.8728
#
# === Time Cut: 3800 ===
# [Epoch 100] Train Loss: 0.3464 | Train Recall: 0.7676 | Train Auc: 0.8916
# [Final Val+Test] Acc: 0.8087 | Prec: 0.7261 | Recall: 0.7412 | AUC: 0.8530
#
# === Time Cut: 3815 ===
# [Epoch 100] Train Loss: 0.3428 | Train Recall: 0.7843 | Train Auc: 0.8999
# [Final Val+Test] Acc: 0.8136 | Prec: 0.7318 | Recall: 0.7391 | AUC: 0.8617
#
# === Time Cut: 3830 ===
# [Epoch 100] Train Loss: 0.3453 | Train Recall: 0.8017 | Train Auc: 0.8993
# [Final Val+Test] Acc: 0.8003 | Prec: 0.7199 | Recall: 0.7518 | AUC: 0.8573
#
# === Time Cut: 3845 ===
# [Epoch 100] Train Loss: 0.3433 | Train Recall: 0.7740 | Train Auc: 0.9041
# [Final Val+Test] Acc: 0.8203 | Prec: 0.7408 | Recall: 0.7434 | AUC: 0.8649
#
# === Time Cut: 3860 ===
# [Epoch 100] Train Loss: 0.3486 | Train Recall: 0.7787 | Train Auc: 0.8934
# [Final Val+Test] Acc: 0.8186 | Prec: 0.7403 | Recall: 0.7609 | AUC: 0.8648
#
# === Time Cut: 3875 ===
# [Epoch 100] Train Loss: 0.3541 | Train Recall: 0.7890 | Train Auc: 0.8984
# [Final Val+Test] Acc: 0.7987 | Prec: 0.7149 | Recall: 0.7374 | AUC: 0.8603
#
# === Time Cut: 3890 ===
# [Epoch 100] Train Loss: 0.3780 | Train Recall: 0.7313 | Train Auc: 0.8861
# [Final Val+Test] Acc: 0.8037 | Prec: 0.7157 | Recall: 0.7087 | AUC: 0.8546
#
# === Time Cut: 3905 ===
# [Epoch 100] Train Loss: 0.3327 | Train Recall: 0.7781 | Train Auc: 0.8978
# [Final Val+Test] Acc: 0.8153 | Prec: 0.7336 | Recall: 0.7348 | AUC: 0.8651
#
# === Time Cut: 3920 ===
# [Epoch 100] Train Loss: 0.3367 | Train Recall: 0.7726 | Train Auc: 0.9015
# [Final Val+Test] Acc: 0.8070 | Prec: 0.7229 | Recall: 0.7321 | AUC: 0.8643
#
# === Time Cut: 3935 ===
# [Epoch 100] Train Loss: 0.3403 | Train Recall: 0.7801 | Train Auc: 0.9003
# [Final Val+Test] Acc: 0.8037 | Prec: 0.7223 | Recall: 0.7486 | AUC: 0.8716
#
# === Time Cut: 3950 ===
# [Epoch 100] Train Loss: 0.3475 | Train Recall: 0.7871 | Train Auc: 0.8913
# [Final Val+Test] Acc: 0.8103 | Prec: 0.7309 | Recall: 0.7582 | AUC: 0.8539
#
# === Time Cut: 3965 ===
# [Epoch 100] Train Loss: 0.3338 | Train Recall: 0.7873 | Train Auc: 0.9140
# [Final Val+Test] Acc: 0.8203 | Prec: 0.7405 | Recall: 0.7327 | AUC: 0.8681
#
# === Time Cut: 3980 ===
# [Epoch 100] Train Loss: 0.3214 | Train Recall: 0.7927 | Train Auc: 0.9074
# [Final Val+Test] Acc: 0.8153 | Prec: 0.7375 | Recall: 0.7667 | AUC: 0.8757
#
# === Time Cut: 3995 ===
# [Epoch 100] Train Loss: 0.3395 | Train Recall: 0.7772 | Train Auc: 0.8908
# [Final Val+Test] Acc: 0.8103 | Prec: 0.7278 | Recall: 0.7396 | AUC: 0.8404
#
# === Time Cut: 4010 ===
# [Epoch 100] Train Loss: 0.3422 | Train Recall: 0.8036 | Train Auc: 0.9043
# [Final Val+Test] Acc: 0.8170 | Prec: 0.7376 | Recall: 0.7545 | AUC: 0.8622
#
# === Time Cut: 4025 ===
# [Epoch 100] Train Loss: 0.3355 | Train Recall: 0.7628 | Train Auc: 0.8999
# [Final Val+Test] Acc: 0.8153 | Prec: 0.7340 | Recall: 0.7401 | AUC: 0.8674
#
# === Time Cut: 4040 ===
# [Epoch 100] Train Loss: 0.3287 | Train Recall: 0.8046 | Train Auc: 0.9078
# [Final Val+Test] Acc: 0.8203 | Prec: 0.7415 | Recall: 0.7540 | AUC: 0.8758
#
# === Time Cut: 4055 ===
# [Epoch 100] Train Loss: 0.3255 | Train Recall: 0.7856 | Train Auc: 0.9176
# [Final Val+Test] Acc: 0.8220 | Prec: 0.7435 | Recall: 0.7524 | AUC: 0.8653
#
# === Time Cut: 4070 ===
# [Epoch 100] Train Loss: 0.3297 | Train Recall: 0.8153 | Train Auc: 0.9122
# [Final Val+Test] Acc: 0.8170 | Prec: 0.7382 | Recall: 0.7598 | AUC: 0.8781
#
# === Time Cut: 4085 ===
# [Epoch 100] Train Loss: 0.3562 | Train Recall: 0.7569 | Train Auc: 0.8893
# [Final Val+Test] Acc: 0.8120 | Prec: 0.7296 | Recall: 0.7380 | AUC: 0.8508
#
# === Time Cut: 4100 ===
# [Epoch 100] Train Loss: 0.3555 | Train Recall: 0.7330 | Train Auc: 0.8902
# [Final Val+Test] Acc: 0.8270 | Prec: 0.7521 | Recall: 0.7237 | AUC: 0.8604
#
# === Time Cut: 4115 ===
# [Epoch 100] Train Loss: 0.3180 | Train Recall: 0.8048 | Train Auc: 0.9089
# [Final Val+Test] Acc: 0.8286 | Prec: 0.7533 | Recall: 0.7727 | AUC: 0.8726
#
# === Time Cut: 4130 ===
# [Epoch 100] Train Loss: 0.3338 | Train Recall: 0.7715 | Train Auc: 0.9068
# [Final Val+Test] Acc: 0.8203 | Prec: 0.7411 | Recall: 0.7487 | AUC: 0.8635
#
# === Time Cut: 4145 ===
# [Epoch 100] Train Loss: 0.3729 | Train Recall: 0.7156 | Train Auc: 0.8836
# [Final Val+Test] Acc: 0.8087 | Prec: 0.7224 | Recall: 0.6986 | AUC: 0.8453
#
# === Time Cut: 4160 ===
# [Epoch 100] Train Loss: 0.3516 | Train Recall: 0.7290 | Train Auc: 0.8954
# [Final Val+Test] Acc: 0.8253 | Prec: 0.7483 | Recall: 0.7333 | AUC: 0.8736
#
# === Time Cut: 4175 ===
# [Epoch 100] Train Loss: 0.3346 | Train Recall: 0.7894 | Train Auc: 0.9019
# [Final Val+Test] Acc: 0.8103 | Prec: 0.7299 | Recall: 0.7529 | AUC: 0.8609
#
# === Time Cut: 4190 ===
# [Epoch 100] Train Loss: 0.3443 | Train Recall: 0.7655 | Train Auc: 0.8900
# [Final Val+Test] Acc: 0.8186 | Prec: 0.7387 | Recall: 0.7449 | AUC: 0.8466
#
# === Time Cut: 4205 ===
# [Epoch 100] Train Loss: 0.3480 | Train Recall: 0.7678 | Train Auc: 0.8890
# [Final Val+Test] Acc: 0.8037 | Prec: 0.7196 | Recall: 0.7353 | AUC: 0.8551
#
# === Time Cut: 4220 ===
# [Epoch 100] Train Loss: 0.3383 | Train Recall: 0.7817 | Train Auc: 0.8964
# [Final Val+Test] Acc: 0.8087 | Prec: 0.7285 | Recall: 0.7545 | AUC: 0.8617
#
# === Time Cut: 4235 ===
# [Epoch 100] Train Loss: 0.3432 | Train Recall: 0.7913 | Train Auc: 0.9067
# [Final Val+Test] Acc: 0.8186 | Prec: 0.7406 | Recall: 0.7636 | AUC: 0.8722
#
# === Time Cut: 4250 ===
# [Epoch 100] Train Loss: 0.3216 | Train Recall: 0.7920 | Train Auc: 0.9036
# [Final Val+Test] Acc: 0.8087 | Prec: 0.7280 | Recall: 0.7518 | AUC: 0.8523
#
# === Time Cut: 4265 ===
# [Epoch 100] Train Loss: 0.2947 | Train Recall: 0.8395 | Train Auc: 0.9264
# [Final Val+Test] Acc: 0.8153 | Prec: 0.7359 | Recall: 0.7561 | AUC: 0.8685
#
# === Time Cut: 4280 ===
# [Epoch 100] Train Loss: 0.3217 | Train Recall: 0.7908 | Train Auc: 0.9063
# [Final Val+Test] Acc: 0.8070 | Prec: 0.7241 | Recall: 0.7401 | AUC: 0.8763
#
# === Time Cut: 4295 ===
# [Epoch 100] Train Loss: 0.3336 | Train Recall: 0.7879 | Train Auc: 0.9039
# [Final Val+Test] Acc: 0.8186 | Prec: 0.7397 | Recall: 0.7556 | AUC: 0.8704
#
# === Time Cut: 4310 ===
# [Epoch 100] Train Loss: 0.3144 | Train Recall: 0.7825 | Train Auc: 0.9152
# [Final Val+Test] Acc: 0.8270 | Prec: 0.7505 | Recall: 0.7609 | AUC: 0.8797
